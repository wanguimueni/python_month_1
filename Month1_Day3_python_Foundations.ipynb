# %% [markdown]
# <a href="https://colab.research.google.com/github/wanguimueni/python_month_1/blob/main/Month1_Day3_python_Foundations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ask user for their name and remove whitespace and capitalize name initials
name = input('what is your name?').strip().title()
first,last=name.split() # Corrected: Changed 'spit' to 'split'
#ask user for their department and remove whitespace and capitalize
department = input('what department do you work for? ').strip().capitalize() # Corrected: Added '()' to call capitalize method
day=input('what part of the day are you enjoying? ').strip()
task=input('what was the most engaging task today? ').strip()
read=input ('what was hard about it? ').strip()
solution =input('how did you go about it? ').strip()
print('Good afternoon, '+ name)
print(f'what department do you work for? {department }')
print('It seems you enjoyed ' + day)
print("Today's task was, " + task + " and the hardest bit about it was " + read)
print('Well, how did you solve it? ' + solution)
# Out:
# what is your name?             becky lee
# what department do you work for?                     IT
# what part of the day are you enjoying?                task  allocation
# what was the most engaging task today?               debugging
# what was hard about it?     error strings and unfinished  parenthesis
# how did you go about it?  adding comments for future reference
# Good afternoon, Becky Lee
# what department do you work for? It
# It seems you enjoyed task  allocation
# Today's task was, debugging and the hardest bit about it was error strings and unfinished  parenthesis
# Well, how did you solve it? adding comments for future reference

# %% [markdown]
# print shouldn't have an equals sign and
# comments can be added after the code
