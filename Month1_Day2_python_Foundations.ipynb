# %% [markdown]
# <a href="https://colab.research.google.com/github/wanguimueni/python_month_1/blob/main/Month1_Day2_python_Foundations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ask user for their name
name = input('what is your name? ')
#remove whitespace from str
name =name.strip()
#capitalize user name
name = name.capitalize()
# say hi to user
print(' hi, ', end="")
print( name)
# Out:
# what is your name? muna
#  hi, muna

# %%
#ask user for their name
name =input('what is your name? ')
#remove whitespaces from str
name = name.strip()
#capitalize user name
name = name.capitalize()
#ask user for their age
age=input('what is your age? ')
#ask user for their hometown
hometown=input('what is your hometown? ')
print("Hello, ", end="")
print(name , age + ' from ' + hometown)
# Out:
# what is your name?                      aarun
# what is your age? 25
# what is your hometown? Nai
# Hello, Aarun 25 from Nai

# %%
# Ask user for their name
name = input('what is your name? ')
# say hi to user
print(' hi , name')
# Out:
# what is your name? mina
#  hi , name

# %%
# Ask user for their name
name = input('what is your name? ')
# say hi to user
print(' \"hi\", ', end="")
print( name)
# Out:
# what is your name? Muna
#  "hi", Muna

# %%
# Ask user for their name
name = input('what is your name? ')
# say hi to user
print(' "hi", ', end="")
print( name)
# Out:
# what is your name? mina
#  "hi", mina

# %%
greeting = ('how are you')
name = input('what is your name? ')
print( greeting , name )
# Out:
# what is your name? Alex
# how are you Alex

# %%
# Ask user for their name
name = input('what is your name? ')
# say hi to user
print(' hi, ', end="")
print( name)
# Out:
# what is your name? mina
#  hi, mina

# %%
# Ask user for their name
name = input('what is your name? ')
# say hi to user
print(' hi, '+ name)
# Out:
# what is your name? Art
#  hi, Art

# %%
name = input('what is your name? ')
position =input("what is your department? ")
print(name + ' works in ' + position)
# Out:
# what is your name? Jay
# what is your department? Finance
# Jay works in Finance
